# %% [markdown]
# <img src="FeatureExtraction.png">

# %%
import cv2
import numpy as np
img = cv2.imread('image.jpg', 0)
img.shape
# Out:
# (400, 400)

# %%
img = cv2.resize(img, (64, 64))
img.shape
# Out:
# (64, 64)

# %%
features = img.flatten()
print(features.shape)
# Out:
# (4096,)
